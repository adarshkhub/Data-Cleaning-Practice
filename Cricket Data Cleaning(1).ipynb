# %%
import pandas as pd

#read in the csv as a dataframe

df = pd.read_csv("C:/Users/adars/Desktop/Practice_Python_Data/Cricket_Data_1.csv")
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  91.76    4   7  1  141  23
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  56.00   10   5  2  104   1

# %%
#Rename multiple columns in the list for better readability 

df = df.rename(columns = {"NO" : "Not_Out", "HS" : "Highest_Innings_Scored", "BF" : "Balls_Faced", "SR" : "Strike_Rate"})

# %%
#Check for Null Values

df.isnull().any()
# Out:
# Player                    False
# Span                      False
# Mat                       False
# Inns                      False
# Not_Out                   False
# Runs                      False
# Highest_Innings_Scored    False
# Ave                       False
# Balls_Faced               False
# Strike_Rate               False
# 100                       False
# 50                        False
# 0                         False
# 4s                        False
# 6s                        False
# dtype: bool

# %%
#Drop Duplicates
df.duplicated()

#No duplicates needed to be dropped
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
#Split up span into start and end date, and eventually create a column to display career length
df['Span'].str.split(pat = "-")
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
# Set the start date as the rookie year column
df['Rookie_Year'] = df['Span'].str.split(pat = "-").str[0]

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  Not_Out  Runs  \
# 0  DG Bradman (AUS)  1928-1948   52    80       10  6996
# 1    HC Brook (ENG)  2022-2023   12    20        1  1181
# 2    AC Voges (AUS)  2015-2016   20    31        7  1485
# 3   RG Pollock (SA)  1963-1970   23    41        4  2256
# 4   GA Headley (WI)  1930-1954   22    40        4  2190
#
#   Highest_Innings_Scored    Ave Balls_Faced  Strike_Rate  100  50  0   4s  6s  \
# 0                    334  99.94       9800+        58.60   29  13  7  626   6
# 1                    186  62.15        1287        91.76    4   7  1  141  23
# 2                   269*  61.87        2667        55.68    5   4  2  186   5
# 3                    274  60.97       1707+        54.48    7  11  1  246  11
# 4                   270*  60.83        416+        56.00   10   5  2  104   1
#
#   Rookie_Year
# 0        1928
# 1        2022
# 2        2015
# 3        1963
# 4        1930

# %%
#Set the end date as final year
df['Final_Year'] = df['Span'].str.split(pat = "-").str[1]

# %%
#Remove the Span Column

df.drop('Span', axis = 1)
# Out:
#                Player  Mat  Inns  Not_Out  Runs Highest_Innings_Scored    Ave  \
# 0    DG Bradman (AUS)   52    80       10  6996                    334  99.94
# 1      HC Brook (ENG)   12    20        1  1181                    186  62.15
# 2      AC Voges (AUS)   20    31        7  1485                   269*  61.87
# 3     RG Pollock (SA)   23    41        4  2256                    274  60.97
# 4     GA Headley (WI)   22    40        4  2190                   270*  60.83
# ..                ...  ...   ...      ...   ...                    ...    ...
# 57   KD Walters (AUS)   74   125       14  5357                    250  48.26
# 58  GC Smith (ICC/SA)  117   205       13  9265                    277  48.25
# 59  WH Ponsford (AUS)   29    48        4  2122                    266  48.22
# 60    SJ McCabe (AUS)   39    62        5  2748                    232  48.21
# 61   DR Jardine (ENG)   22    33        6  1296                    127  48.00
#
# ...

# %%
df.head()
# Out:
#         Player       Span  Mat  Inns  Not_Out  Runs  Highest_Innings_Scored  \
# 0  DG Bradman   1928-1948   52    80       10  6996                     334
# 1    HC Brook   2022-2023   12    20        1  1181                     186
# 2    AC Voges   2015-2016   20    31        7  1485                     269
# 3  RG Pollock   1963-1970   23    41        4  2256                     274
# 4  GA Headley   1930-1954   22    40        4  2190                     270
#
#      Ave  Balls_Faced  Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0  99.94         9800        58.60   29  13  7  626   6        1928
# 1  62.15         1287        91.76    4   7  1  141  23        2022
# 2  61.87         2667        55.68    5   4  2  186   5        2015
# 3  60.97         1707        54.48    7  11  1  246  11        1963
# 4  60.83          416        56.00   10   5  2  104   1        1930
#
#   Final_Year  Country
# 0       1948      NaN
# 1       2023      NaN
# 2       2016      NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df['Country'] = df['Country'].str.split(pat = ")").str[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df.head()
# Out:
#         Player       Span  Mat  Inns  Not_Out  Runs  Highest_Innings_Scored  \
# 0  DG Bradman   1928-1948   52    80       10  6996                     334
# 1    HC Brook   2022-2023   12    20        1  1181                     186
# 2    AC Voges   2015-2016   20    31        7  1485                     269
# 3  RG Pollock   1963-1970   23    41        4  2256                     274
# 4  GA Headley   1930-1954   22    40        4  2190                     270
#
#      Ave  Balls_Faced  Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0  99.94         9800        58.60   29  13  7  626   6        1928
# 1  62.15         1287        91.76    4   7  1  141  23        2022
# 2  61.87         2667        55.68    5   4  2  186   5        2015
# 3  60.97         1707        54.48    7  11  1  246  11        1963
# 4  60.83          416        56.00   10   5  2  104   1        1930
#
#   Final_Year  Country
# 0       1948      NaN
# 1       2023      NaN
# 2       2016      NaN
# ...

# %%
# show the player column without the country 
df['Player'] = df['Player'].str.split(pat = "(").str[0]

# %%
df.head()
# Out:
#         Player       Span  Mat  Inns  Not_Out  Runs  Highest_Innings_Scored  \
# 0  DG Bradman   1928-1948   52    80       10  6996                     334
# 1    HC Brook   2022-2023   12    20        1  1181                     186
# 2    AC Voges   2015-2016   20    31        7  1485                     269
# 3  RG Pollock   1963-1970   23    41        4  2256                     274
# 4  GA Headley   1930-1954   22    40        4  2190                     270
#
#      Ave  Balls_Faced  Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0  99.94         9800        58.60   29  13  7  626   6        1928
# 1  62.15         1287        91.76    4   7  1  141  23        2022
# 2  61.87         2667        55.68    5   4  2  186   5        2015
# 3  60.97         1707        54.48    7  11  1  246  11        1963
# 4  60.83          416        56.00   10   5  2  104   1        1930
#
#   Final_Year  Country
# 0       1948      NaN
# 1       2023      NaN
# 2       2016      NaN
# ...

# %%
# Changing datatype to make data in column more useable
df.dtypes
# Out:
# Player                     object
# Span                       object
# Mat                         int64
# Inns                        int64
# Not_Out                     int64
# Runs                        int64
# Highest_Innings_Scored      int32
# Ave                       float64
# Balls_Faced                object
# Strike_Rate               float64
# 100                         int64
# 50                          int64
# 0                           int64
# 4s                          int64
# 6s                          int64
# Rookie_Year                object
# Final_Year                 object
# Country                    object
# dtype: object

# %%
#Change Highest_Innings_Scored and Balls_Faced to integer type
df.head()
# Out:
#         Player       Span  Mat  Inns  Not_Out  Runs  Highest_Innings_Scored  \
# 0  DG Bradman   1928-1948   52    80       10  6996                     334
# 1    HC Brook   2022-2023   12    20        1  1181                     186
# 2    AC Voges   2015-2016   20    31        7  1485                     269
# 3  RG Pollock   1963-1970   23    41        4  2256                     274
# 4  GA Headley   1930-1954   22    40        4  2190                     270
#
#      Ave  Balls_Faced  Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0  99.94         9800        58.60   29  13  7  626   6        1928
# 1  62.15         1287        91.76    4   7  1  141  23        2022
# 2  61.87         2667        55.68    5   4  2  186   5        2015
# 3  60.97         1707        54.48    7  11  1  246  11        1963
# 4  60.83          416        56.00   10   5  2  104   1        1930
#
#   Final_Year  Country
# 0       1948      NaN
# 1       2023      NaN
# 2       2016      NaN
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df['Balls_Faced'] = df['Balls_Faced'].astype('int64')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
#Balls_Faced has rows with value "-" which can not be converted to int, so replace these rows with 0 then convert to int

df['Balls_Faced'] = df['Balls_Faced'].replace("-","0")

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df['Balls_Faced'] = df['Balls_Faced'].astype("int")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df.dtypes
# Out:
# Player                     object
# Span                       object
# Mat                         int64
# Inns                        int64
# Not_Out                     int64
# Runs                        int64
# Highest_Innings_Scored      int32
# Ave                       float64
# Balls_Faced                 int32
# Strike_Rate               float64
# 100                         int64
# 50                          int64
# 0                           int64
# 4s                          int64
# 6s                          int64
# Rookie_Year                object
# Final_Year                 object
# Country                    object
# dtype: object

# %%
#Create a career length column

df['Final_Year'] = df['Final_Year'].astype("int")
df['Rookie_Year'] = df['Rookie_Year'].astype("int")

# %%
df["Career_Length"] = df['Final_Year'] - df['Rookie_Year']

# %%
df.head()
# Out:
#         Player       Span  Mat  Inns  Not_Out  Runs  Highest_Innings_Scored  \
# 0  DG Bradman   1928-1948   52    80       10  6996                     334
# 1    HC Brook   2022-2023   12    20        1  1181                     186
# 2    AC Voges   2015-2016   20    31        7  1485                     269
# 3  RG Pollock   1963-1970   23    41        4  2256                     274
# 4  GA Headley   1930-1954   22    40        4  2190                     270
#
#      Ave  Balls_Faced  Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0  99.94         9800        58.60   29  13  7  626   6         1928
# 1  62.15         1287        91.76    4   7  1  141  23         2022
# 2  61.87         2667        55.68    5   4  2  186   5         2015
# 3  60.97         1707        54.48    7  11  1  246  11         1963
# 4  60.83          416        56.00   10   5  2  104   1         1930
#
#    Final_Year  Country  Career_Length
# 0        1948      NaN             20
# ...

# %%
#Calculations with the Dataframe

# What is the average career length

df["Career_Length"].mean()
# Out:
# 13.193548387096774

# %%
#Average strike rate for cricketers who played more than 10 years
df[df["Career_Length"] > 10]["Strike_Rate"].mean()
# Out:
# 47.94681818181819

# %%
# Cricketers who played before 1960
df[df["Rookie_Year"] < 1960]
# Out:
#              Player       Span  Mat  Inns  Not_Out  Runs  \
# 0       DG Bradman   1928-1948   52    80       10  6996
# 4       GA Headley   1930-1954   22    40        4  2190
# 5      H Sutcliffe   1924-1935   54    84        9  4555
# 6        E Paynter   1931-1939   20    31        5  1540
# 7    KF Barrington   1955-1968   82   131       15  6806
# 8        ED Weekes   1948-1958   48    81        5  4455
# 9       WR Hammond   1927-1947   85   140       16  7249
# 10       GS Sobers   1954-1974   93   160       21  8032
# 13        JB Hobbs   1908-1930   61   102        7  5410
# 14      CL Walcott   1948-1960   44    74        7  3798
# 15        L Hutton   1937-1955   79   138       15  6971
# 17    GE Tyldesley   1921-1929   14    20        2   990
# 22       AD Nourse   1935-1951   34    62        7  2960
# 30         J Ryder   1920-1929   20    32        5  1394
# 41     DCS Compton   1937-1957   78   131       15  5807
# ...

# %%
# Max Highest Inns Score by Country

df[Highest_Innings_scored].max().groupby("Country")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 # Max Highest Inns Score by Country
# ----> 3 df[Highest_Innings_scored].max().groupby("Country")
#
# NameError: name 'Highest_Innings_scored' is not defined

# %%
# Hundreds, Fifties, and ducks, avg by country
df.groupby("Country")[["100","50","0"]].mean()
